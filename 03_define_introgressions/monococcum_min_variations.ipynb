# %% [markdown]
# # Script to quantify variations minimum of the Triticum monoccocum accesison by windows from IBSpy combined tables by chromsome

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Functions

# %%
def select_genotypes(df, sample_list):
    filter_df = df.set_index(['seqname', 'start', 'end']).filter(items=sample_list, axis=1)
    return filter_df.reset_index()

def file_to_list(file):
    file_l = pd.read_csv(file)['genotype'].tolist()
    return file_l

def get_min(df, list_1, list_2):
    monoc_df = select_genotypes(df, list_1)
    out_df = select_genotypes(df, list_2)
    out_df.insert(3, 'monoccoccum_min', monoc_df.iloc[:, 3:].min(axis=1))
    return out_df

# %% [markdown]
# ##  Arguments

# %%
window = 50000
function = np.sqrt
reference = 'arinalrfor'
data_path ='./IBSpy_tables/'

# %% [markdown]
# ## Input IBSpy variaitons table data

# %%
in_file = pd.read_csv(f'{data_path}/{reference}_combined_queries_{window}w.tsv.gz', delimiter='\t')
in_file
# Out:
#        seqname      start        end  TA10573  TA582  TA571  TA757  TA443  \
# 0        chr1A          1      50000      404    356    364    409    416
# 1        chr1A      50001     100000      316    296    292    320    302
# 2        chr1A     100001     150000      300    531    528    538    551
# 3        chr1A     150001     200000      325    480    486    481    463
# 4        chr1A     200001     250000      101    106     90     95    103
# ...        ...        ...        ...      ...    ...    ...    ...    ...
# 293188   chrUn  464450001  464500000      571    589    585    578    581
# 293189   chrUn  464500001  464550000      486    480    481    476    488
# 293190   chrUn  464550001  464600000      513    522    494    493    496
# 293191   chrUn  464600001  464650000      501    514    486    502    482
# 293192   chrUn  464650001  464700000      813    795    798    814    826
#
#         TA394  TA10418  ...  mace-pg  mattis-pg  norin61-pg  spelt-pg  \
# 0         367      367  ...      458          4         421       459
# 1         290      290  ...      433          2         438       435
# 2         535      530  ...      569          2         603       588
# 3         488      462  ...      543          1         556       582
# 4         103       99  ...      213         19         217       245
# ...       ...      ...  ...      ...        ...         ...       ...
# 293188    592      568  ...      111         87          84       148
# 293189    489      475  ...      103         57         146       117
# 293190    512      500  ...      110         68         106       128
# 293191    500      479  ...      117         50         137       138
# 293192    826      813  ...      261        223         315       230
#
#         stanley-pg  claire2  paragon2  robigus2  weebil2  cadenza2
# 0              428      377       389       374      452       425
# 1              428      420       401       423      450       427
# 2              581      559       565       582      575       555
# 3              532      524       543       542      542       525
# 4              269      189       181       187      208       178
# ...            ...      ...       ...       ...      ...       ...
# 293188         101       46        37        40       21        64
# 293189          81       24        62        55       66        50
# 293190         160        8        38        19       37        72
# 293191          92       78        42       100       50        68
# 293192         290      162       229       142      158       218
#
# [293193 rows x 239 columns]

# %% [markdown]
# ## Filter by sub-genome A

# %%
by_genome = in_file[in_file['seqname'].str.contains('A')].copy()
by_genome
# Out:
#        seqname      start        end  TA10573  TA582  TA571  TA757  TA443  \
# 0        chr1A          1      50000      404    356    364    409    416
# 1        chr1A      50001     100000      316    296    292    320    302
# 2        chr1A     100001     150000      300    531    528    538    551
# 3        chr1A     150001     200000      325    480    486    481    463
# 4        chr1A     200001     250000      101    106     90     95    103
# ...        ...        ...        ...      ...    ...    ...    ...    ...
# 251499   chr7A  756100001  756150000      243    273    264    295    290
# 251500   chr7A  756150001  756200000      319    307    311    321    323
# 251501   chr7A  756200001  756250000      405    327    353    351    377
# 251502   chr7A  756250001  756300000      477    462    465    406    416
# 251503   chr7A  756300001  756350000      426    418    432    468    431
#
#         TA394  TA10418  ...  mace-pg  mattis-pg  norin61-pg  spelt-pg  \
# 0         367      367  ...      458          4         421       459
# 1         290      290  ...      433          2         438       435
# 2         535      530  ...      569          2         603       588
# 3         488      462  ...      543          1         556       582
# 4         103       99  ...      213         19         217       245
# ...       ...      ...  ...      ...        ...         ...       ...
# 251499    261      250  ...       13        170         151       144
# 251500    321      315  ...        9        336         239       271
# 251501    379      337  ...       19        441         453       440
# 251502    417      435  ...        8        423         394       421
# 251503    423      454  ...       17        316         353       341
#
#         stanley-pg  claire2  paragon2  robigus2  weebil2  cadenza2
# 0              428      377       389       374      452       425
# 1              428      420       401       423      450       427
# 2              581      559       565       582      575       555
# 3              532      524       543       542      542       525
# 4              269      189       181       187      208       178
# ...            ...      ...       ...       ...      ...       ...
# 251499         220        5       149         5      209       210
# 251500         274       21       273        23      285       272
# 251501         433       25       448        16      437       447
# 251502         423        3       427         2      434       419
# 251503         261        5       344         5      263       249
#
# [99403 rows x 239 columns]

# %% [markdown]
# ## Get monococcum minimum variaitons count by window

# %%
monoc_list = file_to_list('monococcum_genotypes.tsv')
genotypes_list = file_to_list('genotypes.tsv')
min_df = get_min(by_genome, monoc_list, genotypes_list)
min_df
# Out:
#       seqname      start        end  monoccoccum_min  TA10573  TA582  TA571  \
# 0       chr1A          1      50000              350      404    356    364
# 1       chr1A      50001     100000              271      316    296    292
# 2       chr1A     100001     150000              257      300    531    528
# 3       chr1A     150001     200000              258      325    480    486
# 4       chr1A     200001     250000               79      101    106     90
# ...       ...        ...        ...              ...      ...    ...    ...
# 99398   chr7A  756100001  756150000              219      243    273    264
# 99399   chr7A  756150001  756200000              253      319    307    311
# 99400   chr7A  756200001  756250000              237      405    327    353
# 99401   chr7A  756250001  756300000              234      477    462    465
# 99402   chr7A  756300001  756350000              334      426    418    432
#
#        TA757  TA443  TA394  ...  mace-pg  mattis-pg  norin61-pg  spelt-pg  \
# 0        409    416    367  ...      458          4         421       459
# 1        320    302    290  ...      433          2         438       435
# 2        538    551    535  ...      569          2         603       588
# 3        481    463    488  ...      543          1         556       582
# 4         95    103    103  ...      213         19         217       245
# ...      ...    ...    ...  ...      ...        ...         ...       ...
# 99398    295    290    261  ...       13        170         151       144
# 99399    321    323    321  ...        9        336         239       271
# 99400    351    377    379  ...       19        441         453       440
# 99401    406    416    417  ...        8        423         394       421
# 99402    468    431    423  ...       17        316         353       341
#
#        stanley-pg  claire2  paragon2  robigus2  weebil2  cadenza2
# 0             428      377       389       374      452       425
# 1             428      420       401       423      450       427
# 2             581      559       565       582      575       555
# 3             532      524       543       542      542       525
# 4             269      189       181       187      208       178
# ...           ...      ...       ...       ...      ...       ...
# 99398         220        5       149         5      209       210
# 99399         274       21       273        23      285       272
# 99400         433       25       448        16      437       447
# 99401         423        3       427         2      434       419
# 99402         261        5       344         5      263       249
#
# [99403 rows x 240 columns]

# %% [markdown]
# ## Split by chromosome & save tables

# %%
chromosomes = ('chr1A', 'chr2A', 'chr3A', 'chr4A', 'chr5A','chr6A','chr7A')
for chromosome in chromosomes:
    chrom_ind = min_df[min_df['seqname'].str.contains(chromosome)].copy()
    chrom_ind.to_csv(f'{reference}_{chromosome}_variations_all_genotypes.tsv', sep='\t', index=False)
